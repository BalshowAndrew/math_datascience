# %% [markdown]
# # Домашнее задание "Центральная предельная теорема и статистика"

# %% [markdown]
# ## Задание

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.
#
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n. Постройте гистрограммы средних этих выборок и сделайте выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %%
s = 0.954
rv = sts.lognorm(s)
sample = rv.rvs(size=10000)

# %%
x = np.linspace(0,20,1000)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=300, alpha=0.5, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.title('lognorm')
plt.legend()
plt.ylabel('fraction of samples')
plt.xlabel('x')
plt.show()

# %%
for n in [2, 10, 30, 50, 100]:
    a = np.array([])
    for number in range(1000): 
        sample = rv.rvs(size=n)
        a = np.append(a, sample.mean())  
    plt.hist(a, density=True, label=label, alpha = 0.7, bins=50)
    plt.title(f"Sample of {str(n)} histogram")
    plt.ylabel('samples means')
    plt.xlabel('')
    plt.show()

# %% [markdown]
# Вывод: уже при выборке от 30 и выше рапределение средних значений близко к нормальному.
